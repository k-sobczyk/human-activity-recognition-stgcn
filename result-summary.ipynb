# %% [markdown]
# # Model Overview and Results Summary

# %%
from src.model.st_gcn import  *
from sklearn.metrics import classification_report

# %%
model, test_loader = run_training(use_wandb=False)
# Out:
# Creating sequences...
# Created 261 sequences of shape (261, 64, 8, 3)
#
# Splitting into train/test sets...
#
# Training samples: 208
# Testing samples: 53
# Number of classes: 16
# Sequence shape: (261, 64, 8, 3)
# C:\Users\Happy\Documents\Studia - sem2\human-activity-recognition-stgcn\.venv\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch [1/100] - LR: 0.001000
# Train Loss: 2.6952 | Accuracy: 0.0769
# Val Loss: 2.7398 | Accuracy: 0.2453
# ----------------------------------------
# Epoch [2/100] - LR: 0.001000
# Train Loss: 2.4526 | Accuracy: 0.2981
# Val Loss: 2.6932 | Accuracy: 0.2453
# ----------------------------------------
# Epoch [3/100] - LR: 0.001000
# Train Loss: 2.2270 | Accuracy: 0.4038
# Val Loss: 2.5902 | Accuracy: 0.4717
# ----------------------------------------
# Epoch [4/100] - LR: 0.001000
# Train Loss: 2.0746 | Accuracy: 0.4135
# ...

# %%
model.eval()
y_pred = []
y_true = []

with torch.no_grad():
    for inputs, labels in test_loader:
        outputs = model(inputs)

        _, preds = torch.max(outputs, 1)

        y_pred.extend(preds.cpu().numpy())
        y_true.extend(labels.cpu().numpy())

# %%
class_names = [f"Class {i}" for i in range(-1, 16)]

report = classification_report(y_true, y_pred, labels=list(range(-1, 16)), target_names=class_names, zero_division=0)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#     Class -1       0.00      0.00      0.00         0
#      Class 0       0.82      0.69      0.75        13
#      Class 1       0.74      1.00      0.85        14
#      Class 2       1.00      1.00      1.00         1
#      Class 3       1.00      0.50      0.67         2
#      Class 4       1.00      1.00      1.00         2
#      Class 5       1.00      1.00      1.00         2
#      Class 6       1.00      1.00      1.00         1
#      Class 7       1.00      1.00      1.00         2
#      Class 8       1.00      1.00      1.00         2
#      Class 9       0.00      0.00      0.00         2
#     Class 10       1.00      1.00      1.00         2
#     Class 11       0.67      1.00      0.80         2
#     Class 12       1.00      1.00      1.00         2
#     Class 13       0.67      1.00      0.80         2
#     Class 14       0.00      0.00      0.00         2
# ...
